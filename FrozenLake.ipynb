# %%
import gym
import pygame
from algorithms.rl import RL
from algorithms.planner import Planner
from examples.test_env import TestEnv

frozen_lake = gym.make('FrozenLake8x8-v1', render_mode=None)

# %%
Q, V, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=1000000)
Plots.grid_values_heat_map(V, "State Values")
# Out:
# runtime = 1263.84 seconds

# %%
Q, V, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=50000)
Plots.grid_values_heat_map(V, "State Values")
# Out:
# runtime = 65.24 seconds

# %%
Q, V, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=100000)
Plots.grid_values_heat_map(V, "State Values")
# Out:
# runtime = 131.28 seconds

# %%
Q, V, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=500000)
Plots.grid_values_heat_map(V, "State Values")
# Out:
# runtime = 663.47 seconds

# %%
#grid search
from examples.grid_search import GridSearch
epsilon_decay = [.99]
iters = [10, 50, 100, 500, 1000, 2000, 5000, 10000, 20000, 50000]
GridSearch.Q_learning_grid_search(frozen_lake.env, epsilon_decay, iters)
# Out:
# running -- with epsilon decay:  0.99  iterations:  10
# runtime = 0.02 seconds
# running -- with epsilon decay:  0.99  iterations:  50
# runtime = 0.10 seconds
# running -- with epsilon decay:  0.99  iterations:  100
# runtime = 0.18 seconds
# running -- with epsilon decay:  0.99  iterations:  500
# runtime = 0.85 seconds
# running -- with epsilon decay:  0.99  iterations:  1000
# runtime = 1.73 seconds
# running -- with epsilon decay:  0.99  iterations:  2000
# runtime = 3.59 seconds
# running -- with epsilon decay:  0.99  iterations:  5000
# runtime = 8.53 seconds
# running -- with epsilon decay:  0.99  iterations:  10000
# runtime = 17.44 seconds
# running -- with epsilon decay:  0.99  iterations:  20000
# runtime = 34.58 seconds
# running -- with epsilon decay:  0.99  iterations:  50000
# runtime = 62.73 seconds

# %%
epsilon_decay = [.99]
iters = [75000, 100000, 120000,150000,200000]
GridSearch.Q_learning_grid_search(frozen_lake.env, epsilon_decay, iters)
# Out:
# running -- with epsilon decay:  0.99  iterations:  75000
# runtime = 94.53 seconds
# running -- with epsilon decay:  0.99  iterations:  100000
# runtime = 124.57 seconds
# running -- with epsilon decay:  0.99  iterations:  120000
# runtime = 149.23 seconds
# running -- with epsilon decay:  0.99  iterations:  150000
# runtime = 187.02 seconds
# running -- with epsilon decay:  0.99  iterations:  200000
#  58%|█████████████████████████████████████████▉                               | 115015/200000 [02:09<01:47, 791.06it/s]

# %%
#plot state values
from examples.plots import Plots
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=10)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=50)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=100)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=200)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=500)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=750)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1000)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1100)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1200)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1300)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1426)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1500)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=2000)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=3000)
Plots.grid_values_heat_map(V, "State Values")
# Out:
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\algorithms\planner.py:76: UserWarning: Max iterations reached before convergence.  Check theta and n_iters.
#   warnings.warn("Max iterations reached before convergence.  Check theta and n_iters.  ")
# runtime = 0.00 seconds
# runtime = 0.02 seconds
# runtime = 0.04 seconds
# runtime = 0.08 seconds
# runtime = 0.19 seconds
# runtime = 0.29 seconds
# runtime = 0.38 seconds
# runtime = 0.42 seconds
# runtime = 0.46 seconds
# runtime = 0.49 seconds
# runtime = 0.54 seconds
# runtime = 0.54 seconds
# runtime = 0.54 seconds
# runtime = 0.54 seconds

# %%
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=1)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=2)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=3)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=4)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=5)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=6)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=7)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=8)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=9)
V, V_track, pi = Planner(frozen_lake.env.P).value_iteration(gamma=1, n_iters=10)
# Out:
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# runtime = 0.00 seconds
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\algorithms\planner.py:76: UserWarning: Max iterations reached before convergence.  Check theta and n_iters.
#   warnings.warn("Max iterations reached before convergence.  Check theta and n_iters.  ")

# %%
from examples.plots import Plots
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=2)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=3)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=4)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=5)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=6)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=7)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=8)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=9)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=10)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=11)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=50)
Plots.grid_values_heat_map(V, "State Values")
# Out:
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\algorithms\planner.py:136: UserWarning: Max iterations reached before convergence.  Check n_iters.
#   warnings.warn("Max iterations reached before convergence.  Check n_iters.")
# runtime = 0.00 seconds
# runtime = 0.06 seconds
# runtime = 1.07 seconds
# runtime = 1.46 seconds
# runtime = 0.90 seconds
# runtime = 2.73 seconds
# runtime = 2.72 seconds
# runtime = 3.09 seconds
# runtime = 2.64 seconds
# runtime = 2.13 seconds
# runtime = 3.45 seconds
# runtime = 3.25 seconds

# %%
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=10)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=50)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=100)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=200)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=500)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=750)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1000)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1100)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1200)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1300)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1426)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=1500)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=2000)
V, V_track, pi = Planner(frozen_lake.env.P).policy_iteration(gamma=1, n_iters=3000)
# Out:
# runtime = 2.74 seconds
# runtime = 3.28 seconds
# runtime = 2.64 seconds
# runtime = 2.97 seconds
# runtime = 2.98 seconds
# runtime = 3.29 seconds
# runtime = 3.33 seconds
# runtime = 2.77 seconds
# runtime = 2.99 seconds
# runtime = 3.30 seconds
# runtime = 3.30 seconds
# runtime = 3.74 seconds
# runtime = 3.28 seconds
# runtime = 3.36 seconds

# %%
# Q-learning
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=50)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=100)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=500)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=1000)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=2000)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=5000)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=7500)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=10000)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=20000)
Q, V2, pi, Q_track, pi_track = RL(frozen_lake.env).q_learning(n_episodes=50000)
Plots.grid_values_heat_map(V2, "State Values")

# %%
test_scores = TestEnv.test_env(env=frozen_lake.env, render=True, user_input=False, pi=pi)
PRINT(test_scores)
